# %%
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_airline_codes')[0][['ICAO']]

# %%
df.to_csv('airline_codes.csv', index = False)

# %%
list(pd.read_csv('data/raw_data/airline_codes.csv')['ICAO'].dropna())
# Out:
# ['BOI',
#  'EVY',
#  'GNL',
#  'TBS',
#  'WYT',
#  'TFU',
#  'CHD',
#  'TTF',
#  'TWF',
#  'SEC',
#  'MLA',
#  'QRT',
#  'PIU',
#  'ASD',
#  'SEK',
#  'AIJ',
#  'XRC',
#  'UBE',
#  'RYA',
#  'BRO',
#  'GBT',
#  'AJR',
#  'SFM',
#  'AJJ',
#  'XXV',
#  'BBE',
#  'ABJ',
#  'NKP',
#  'ABG',
#  'ABE',
#  'MRP',
#  'AHU',
#  'FTY',
#  'AAB',
#  'BDV',
#  'ROH',
#  'ADJ',
#  'ABP',
#  'TUS',
#  'TTN',
#  'ABX',
#  'IAE',
#  'NCL',
#  'ACD',
#  'CYD',
#  'CFM',
#  'ARO',
#  'AES',
#  'BVR',
#  'BJT',
#  'CRV',
#  'ORS',
#  'AXQ',
#  'AVR',
#  'RRM',
#  'ADC',
#  'VUE',
#  'ADE',
#  'DHI',
#  'ADK',
#  'ADW',
#  'DSC',
#  'DDS',
#  'ADF',
#  'TEC',
#  'SWH',
#  'ADR',
#  'DRO',
#  'ADV',
#  'AXX',
#  'AAX',
#  'XTJ',
#  'WSN',
#  'ADD',
#  'ADV',
#  'RDD',
#  'DVN',
#  'EBS',
#  'AEE',
#  'ALS',
#  'AEF',
#  'DRD',
#  'FUT',
#  'MMG',
#  'AGI',
#  'WWG',
#  'AED',
#  'AKR',
#  'RRB',
#  'CND',
#  'ARP',
#  'AEK',
#  'EPU',
#  'XPN',
#  'AJP',
#  'OWN',
#  'GHM',
#  'GLM',
#  'GUE',
#  'ASR',
# ...

# %%
! pwd
# Out:
# /home/stuart/code/stuhow/airline_sentiment
