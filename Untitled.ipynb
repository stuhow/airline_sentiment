# %%
import pandas as pd
import pickle
from tensorflow.keras import models
from tensorflow.keras.preprocessing.sequence import pad_sequences
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import unidecode
import contractions
import re

# %%
def get_airline_codes():
    airport_code_list = list(pd.read_html('https://en.wikipedia.org/wiki/List_of_airline_codes')[0]['ICAO'].dropna())
    return airport_code_list


def clean(text, airport_code_list):

    for air_code in airport_code_list: # remove airline codes
        text = text.replace(air_code, ' ')

    text = text.lower() # Lower Case

    text = re.sub("@[A-Za-z0-9_]+","", text) # remove mentions
    text = re.sub("#[A-Za-z0-9_]+","", text) # remove hashtags

    text = re.sub(r"http\S+", "", text) # remove links
    text = re.sub(r"www.\S+", "", text) # remove links

    expanded_words = [contractions.fix(word) for word in text.split()] # remove contractions

    text = ' '.join(expanded_words) # join words

    unaccented_string = unidecode.unidecode(text) # remove accents

    tokenized = word_tokenize(unaccented_string) # Tokenize

    stop_words = set(stopwords.words('english')) # Make stopword list

    stop_word_to_keep = ['was', 'are', 'did', 'been', 'have', 'until', 'while', 'about', 'against', 'between', 'during', 'before', 'after', 'again', 'when', 'where', 'why', 'how', 'any', 'not', 'no','very', "aren't", "wasn't", "shouldn't", "should", "won't", "wouldn't"]

    stop_words = [x for x in stopwords.words('english') if x not in stop_word_to_keep]

    without_stopwords = [word for word in tokenized if not word in stop_words] # Remove Stop Words

    lemmatizer = WordNetLemmatizer() # Instantiate lemmatizer

    lemmatized = [lemmatizer.lemmatize(word) for word in without_stopwords] # Lemmatize

    lemmatized = " ".join(lemmatized)

    return lemmatized

# %%
df = pd.read_csv('data/raw_data/new tweets.csv')
df['date'] = pd.to_datetime(df['date']).dt.date

# %%
df.head()
# Out:
#          date                                               text
# 0  2023-02-09  Bunker Labs is partnering with @United to laun...
# 1  2023-02-09  Most active airlines - Feb 09,2023🌎🌍🌏\n\n1 - @...
# 2  2023-02-09  Congrats to our @RSWAirport NPS winners, Kelli...
# 3  2023-02-09  Continent number 7 here I come ✅\n\n#Antarctic...
# 4  2023-02-09  Congratulations to PAPA Member Michael Choe wh...

# %%
X_pred = df['text'].astype("str")

# %%
airport_code_list = get_airline_codes()

X_pred = [clean(tweet, airport_code_list) for tweet in X_pred]

# %%
X_pred
# Out:
# ["bunker lab partnering launch mileageplus ( r ) mile mission campaign . campaign allows people donate mile support travel veteran entrepreneur bunker lab ' training & amp ; workshop . donate mile today !",
#  'active airline - feb 09,2023 1 - 2 - 3 - find data :',
#  'congrats irport np winner , kelli , ted & amp ; karen ! along peer helped boost performance holiday . helped outperformed industry during last month 2022 .',
#  'continent number 7 come bound check penguin whale make sure are good . drake passage better nice .',
#  'congratulation p member michael choe recently began training ! michael retired navy after 20-year career flying boeing 737 united . social',
#  "great success , winning bronze `` agent demand ''",
#  'leave overbook flight . get bodyslammed mf going jail .',
#  'weekend , volunteer program brought visited pack meal ! volunteer joined former & amp ; bobbie howard . end visit , volunteer packed 5,000 pound food ! q',
#  'p j r -- r rd n 1/30/23 wa flight ua510 & gt ; & amp ; left journal seat pocket . includes longhand writing inside , photo , cartoon , washi tape decoration & amp ; precious . name & amp ; address are inside front cover . look like :',
#  'why did get z pqp ? p71czjn',
#  ', flight booked 3rd party airliner delayed flight , delayed again span 20 min delayed again before canceling . have go back rep rebook flight takeoff time canceled flight . sameshittyairline',
#  'name snackbox :',
#  'regretting not buying business class seat concerned dog safty flight .',
#  'hey , happened seat ? used able fit in-cabin pet carrier seat . hmm .. think something afetybrief need look . carrier compliant yet seat have gotten smaller',
#  '3 flight week , 2 flight delayed hour . 1 delay night 58 minute flight . far have been 5 plane 3 mechanical issue . hope 6th plane get home before tomorrow .',
#  'zone look good .',
#  'look like amazing trip',
#  'capt . corey shepard 737 captain , quality control line check pilot & amp ; evaluator . while performing leadership duty , maintains active flight schedule . graduated 2002 life member aa roud #',
#  'good morning ! happy thursday everyone ! sfo , where',
#  'fine people yvr , especially staff : may traffic light always green , may never wait line , may win lottery . lost very important item , moved heaven earth get back before door plane closed .',
#  'totally disgusted . booked economy ticket , selected seat next family , received confirmation email told ( incorrectly ) booked basic economy fare . 90 min wasted customer service .',
#  "today 's best deal : chicago . leave may 6 , return home may 13 . $ 148 roundtrip . love when airfare destination not always cheap actually cheap .",
#  'hey , need help math : buy mile : ( 50 % discount ) $ 3,026=175k mile $ .0173 per mile cash mile : 320,400 miles= $ 3,204 $ .01 per mile 42 % differential buy mile 175k mile , are worth 73k when go cash ? ?',
#  "`` before got flying , did not know any pilot -- did not know anyone aviation anything like . actually kind fell , '' said cpt . kirkpatrick about importance representation , especially aviation !",
#  '. b737 named after 1950s veteran flew grumman albatross sar aircraft . continental airline refused hire based race . unanimous 1963 # decision ruled favour . read d3e',
#  'have been moping around since losing gold status despite aggressive return business travel . imagine surprise delight getting upgraded morning . great start day ! thank , !',
#  'received worst customer service @ _air portugal . spent 47k frequent flier mile upgrade exec class due delay caused missed flight . refuse refund mile . not believe treat customer like irlines',
#  'remind never ever fly again . taking day trip . no bag . early flight . tsa pre . not checkin online basic airfare . c said not overwrite when called even though see flight back day . wa rude . ugh !',
#  'flying morning . pray strength .',
#  'next stop ... nyc 4 sushi opening weekend ! via ( @ louisville muhammad ali international airport - louisville , ky )',
#  'one flight day cancel ... good job uniting , ua60',
#  'hey not sell ticket get fams stranded airport night . got sfo sin 9pm , n flight 10:40am not let u check , top kiosk go oos start print bag tag . are stuck . inc 5yr old .',
#  'not understand why 2023 not comfortable seat economy tall not have space small seat foot',
#  'flight crew wa next level trip ! remembered u name flight rome are sweet .',
#  'hey ! captain bo , ua957 9 february made everyone day gva . shook everyone hand , took pic kid , welcomed u pa gate . legend !',
#  'transit time ufff .. almost missed flight thanks f26',
#  'air india sfo worst aircraft have ever misfortune fly . everything filthy broken . not suspended direct flight operation route .',
#  'thanks',
#  'one couple brand new 787-10s turn runway 16r seemed b2 last week .',
#  'been stuck already landed flight almost hour half tell u brow exit aircraft broken . awesome see tax yet again !',
#  "ever have chance fly polaris first . first class whole level . amazing ! full stop . also . pissed , owe $ 100 ( would argue ) return trip . bumped plus regular . 6 ' 6 '' . 1 2",
#  'hey ruined ski trip plane wa overweight decided not put any gear . flew bought lift ticket nothing . right thing issue refund .',
#  'four flight week . wi-fi functioning exactly zero .',
#  "clear indication somaliland army bombed las'anod . @ - international cricket council right watch somalia nation",
#  'overnight baltimore ... #',
#  'good option frequent traveler ? use after today done . 2 delayed flight totaling g 10 hour , lost bag , no food voucher .... think done . happening often . wasted vacay day 800 dollar plus lost bag expense',
#  'when bos go around plane give team treat ! ! ! ! thank',
#  'hey real ? lhr - akl agcfvzn',
#  'term climate , feedstock availability , even pipeline available , virginia lead way best state sustainable aviation fuel production . commitment buy would result refinery tg4391i',
#  'anyone have start booking reservation return hold told fare gone ? bought extra mile confirm reservation want . much mileage plus member .',
#  'anyone follows know correct would not risk lawsuit',
#  'much loyalty program get help someone ? lifetime member promise !',
#  'look like might not coming & amp ; tonight tomorrow afternoon instead .',
#  'treat ! thank serve team sfo member during flight back home . have made flight enjoyable .',
#  'people say want about told about rough week have customer service guy wa understanding helped credit two plane ticket within 48hr departure .',
#  'expected carry movie streaming list february ! ...',
#  'top . @ airport charged additional $ 21 exit parking lot c , took 45 minute get . pushed hour anticipated arrival time . something need get done',
#  'flight ua4434 , wa delayed first 1 hour landed 8.10pm 9.03pm still complete halt not allowed go gate',
#  'dear r ? dark brandon coming after shady way',
#  'again old shit @ airport would let united flight go towards gate dc make u sit 45 min ... pathetic situation soon stop flying',
#  'connection flight lost',
#  'wrong airline industry ? ! second time two month , flight have been majorly impacted maintenance issue plane . flight wa delayed pvr houston , causing u miss connection houston denver .',
#  "`` really appreciate status , one fly while '' ~ old chinese proverb",
#  'happened again . fly @ airport depart terminal c bet not arrival term c. not park one terminal think convenient get term c term a. nope . add 45 min trip . unbelievable .',
#  "one united 's best , tania created beautiful",
#  'hey - busted plane , gate change , broken jetways . multiple delay crappy communication . maybe operating airline not thing ?',
#  'thank great day den',
#  'send prayer airline god . 6 hour delay definitely not make home tonight .',
#  'n n g are celebrating new brand giveaway ! navan user enter chance win 2 nd p 2 annual club membership ( $ 4k value ) . entry deets term & amp ; condition :',
#  'connecting people , uniting world ... during holiday & amp ; beyond ! proud part caring , safety focused , driven , dedicated - denver team ! rt sn peek click among first see local',
#  'god would rather submitted kind medieval torture have fly again . lost baggage are still refusing payout . anybody know good aviation lawyer ?',
#  'suddenly find great friend ally caribbean region . thanks making always available showing compassion empathy everything . # eadershipconf oc',
#  "when did stop boarding first class first ? like , part `` first class '' not resonating ?",
#  "thank find return daughter 's phone missed plane during one rushed connection . gr job guy !",
#  "cousin ' experience flight 2390 , seat 34j , 1/25/23 , . plane remained tarmac 4+ hour , ( combined take arrival ) . no amenity passenger given . not ok. cousin 1k member . passenger should reimbursed mile",
#  "leader across sharing story , reminiscing past , leading way united 's bright future . # eadershipconf",
#  'enemy are mocking',
#  '# eadershipconf latin-southamerican leader smiling showing how story airline when good lead way .',
#  ". grad california native phil griffith vice president united airline ' houston hub . defender recently spoke phil griffith about current leadership role airline life experience brought moment .",
#  'flight , 5036 salina , kansa chicago , sparsely populated ready 1 hour , 8 minute flight bit turbulence ahead .',
#  'love !',
#  'like bluetooth wireless option headphone - should have used previous flight',
#  'hello , have requested status match ba website . included screen dump ba card wa denied . proof should send ? thanks !',
#  "1st look inside 's retrofitted boeing 767-400er , final fleet type receive polaris business class premium plus seat . thread ( 1/12 )",
#  "`` customer service '' department told 13hr delay wa `` small delay '' would not offer any voucher consideration . talk airport online again phone . how customer service dead ! ! ?",
#  'no country have capacity accommodate nigeria refugee ! should save nigeria . nothing working anymore . judiciary currently joke',
#  ". taking aim . last year wa `` southwest courte-c call . '' united plan run ad denver colorado spring market during super bowl , highlighting operational performance southwest . 9v4whqca",
#  'hey time wash bird ua 2624 den',
#  'new email message sending colorado-based mileageplus member . wonder respond .',
#  'would like recognize first officer jamie bainbridge chivalrous action helping flight attendant replace flat tire employee parking lot rainy day before trip . hearing story make proud fellow united pilot !',
#  'departing feltham park back 21st january 2023 787-9 dreamliner registered n19951 .',
#  'non-stop , texas ( & amp ; vice versa ) $ 134 roundtrip ( feb-mar date ) wre7c9k',
#  'when sf c meet de c . c',
#  'not single airline br enough l sale prove wrong . least 20 % flight , day destination no exception least 3 day ! !',
#  'feel great connect leader .',
#  "pilot quote shakespeare tell u plane need replaced : `` when sorrow come , come not single spy , battalion . '' guess nice could expect ...",
#  "arthur fykes iv , bj '13 , manager global advertising social medium operation . attribute level success field support friend made professor while studying j-school .",
#  'team recently proved expertise handling unexpected situation . team assisted diverted united airline boeing 777-200 carrying 326 passenger , en route chicago la vega . thank sending team assist . |',
#  'non-stop , mexico houston , texas $ 250 usd roundtrip ( feb-mar date )',
#  'have been deplaned before due maintenance issue & amp ; switching plane not know have been ever been deplaned * twice * before even taking . boarding 3rd time see bird actually get air . rough day today .',
#  'not complainer , wa trying charge phone find did not charge , charge charge phone . talk about junk fee ! ! !',
#  'run march - have left ! team foundling member get guaranteed admission perk ! learn :',
#  ', oregon toronto , canada $ 282 roundtrip ( mar-may date )',
#  'sfo mt are ready united next .',
#  'cleaning email deleted boarding pas ... been minute ! flight wa actually whole saga ... def',
#  'happy birthday , very ! wonderful leader , mentor amazing cheerleader everyone ! truly ! have blast enjoy special day ! business office family !',
#  "about month ago missed friend funeral flight broke . pilot heard saying `` plane fucked '' . response complaint about missing funeral wa `` should have planned better '' . guess whole airline fucked .",
#  'why not use paypal account pay flight ? not like using card n putting info online',
#  'giving back community encouraging local unity ,',
#  'sky livery .',
#  'flew 10 time last year did not qualify retain basic silver status . have no incentive stay loyal year . airline are frustrating nowadays ! !',
#  'non-stop ( & amp ; vice versa ) $ 90 roundtrip ( feb-apr date )',
#  'hey , please tell pilot today intro wa e & amp ; ask keep info & amp ; site fly going thru whole flight ! ! essence !',
#  "dear not think know meaning word `` momentarily , '' not `` 48 hour counting . '' after have endured get point submitting reimbursement expense per instruction , maybe would faster drive houston & amp ; deliver ?",
#  'forgot mention when booked , wa no seat assignment . when later got one online , charged additional fee !',
#  "have not traveled while , not allow full-size carry-on 's economy , make check , charge extra $ 35 ! ! ? air travel seems get worse every year .",
#  'thanks facilitating session today . are great .',
#  'relief hit different 38,000 ft. lott work stress- find way really believe wa proud one . thanks great wifi , passed step 1 ! !',
#  'get 10,000 bonus mile priority boarding',
#  'used able book flight see mom oregon 24k reward mile . flight , during non-peak time year , 47k mile .',
#  "`` laptop fire cabin . fire plane cabin : 4 people taken hospital after laptop 'ignited ' during flight .",
#  'united pitched super bowl ad take jab . ad short , low production value , air denver colorado spring . yet somehow getting coverage beyond colorado . medium are',
#  'meet airline america ! register feb 10 best rate conference access including $ 300 registration fee !',
#  'not status quo super bowl commercial ..... instead , showcasing wonderful team den ( + c + ) + + + +',
#  'when fly gate irport , feel great sense betrayal',
#  'along awesome intake one receives conference . thing take cake catching friend met along year service . sharing story , reminiscing past & amp ; debating future ! e',
#  '. knowingly put u flight after wa delayed technical issue turn u back around mid flight .',
#  'come plane back take are turning around ? are',
#  '. gate agent commit when charge something free website term . .',
#  'club san antonio , tx rildna9',
#  'instead simply refunding expensive flight canceled due mismanagement , make refund process extremely difficult . intentionally assume . why ?',
#  'happy 2nd anniversary thank amazing two year . # team',
#  "`` breaking chain '' panel chain ! o2023",
#  'have been listening first airline showcase today .',
#  "well , day got million time worse . h wa worst part day . when landed newark , started feel sick . within minute , wa vomiting middle terminal ! thanks `` incredible '' meal give food poisoning .",
#  'congratulation epic grad alexandra orr continues soar aviation career ! alex first officer flying boeing 777 ! alex , are proud ! see are eligible train epic pilot : tw0',
#  'give rebooking business customer economy , without offering compensation . sitting frankfurt airport without even apology ! !',
#  '. original domestic flight allowed free carry since wa connecting international flight . return leg , should also free , staff trying charge $ 35 single c checked . .',
#  'start day right !',
#  "yesterday prompted -to- flight 's return second after take-off . 7 , 4 , authority said . not checked .",
#  ". `` end holiday , biggest competitor eager say would fixed problem , would gotten operation stabilized , would entered software patch , would hired consultant problem solved . not true . ''",
#  '. focusing how continue operationally outperform irport . 7apt2jr',
#  'term business class checkin lounge win hand . make others look overpriced amuterish .',
#  "new ad run during denver colorado spring , highlighting irport operation : `` united got family denver holiday any airline . despite weather . '' 9v4whqca",
#  "love , workhorse fleet . easy load built like tank . @ london heathrow terminal 2 - queen 's terminal",
#  'recently spoke learn about exciting new calibrate apprenticeship programme , launching year !',
#  'friend idol , katherine v ! thanks celebrating 4-million milestone ! next ! n !',
#  'laptop battery fire force flight land , hospitalizes 4 - washington post',
#  'know want united mileage plus explorer card ? not hear about united mileage plus explorer card every time fly . work card benefit next year ?',
#  'turf war : put biggest jet new after unveils new route - point guy',
#  'hey premier access first class flight not get access lounge b/c flight not direct ! ? worked three 13 hr shift row icu- coming tonight . let get peace quiet ? ? literally cry tired',
#  'finally got dreaded email telling have gold status instead 1k . oh well , wa fun while lasted !',
#  'steamy 757 tail , brought . irport',
#  'kind funny sent survey after way wa treated . told how shitty wa , bet no one even read . still felt good tell .',
#  'damn did miss email where upped pqf 24 pqp 8,000 gold status',
#  'excluding white male hiring process , how impact safety ? woman likely have higher retention rate previously though - are required inject covid treatment have reduced fertility rate about 20 % .',
#  'current price ticket dc orlando departing 4/1 returning 4/7 . should ashamed',
#  'best day are never one spent call , making powerpoints . are one get spend people . one get 1 make sure 5am flight go time . one work . are best day . # ome # w',
#  "shout ricardo , one flight attendant flight ( 704 ) sat holding passenger 's sleeping baby mom could get not disturb youngin ( u around ) !",
#  'should have gotten selfie , big big s/o nathan terry atlanta flight ua1358 newark tonight ! ! are really trying woo delta',
#  'going month since told issue been escalated would reached after pet mistreated misled flight still no correspondence . have received zero response friendly status inquires either . lie ever stop',
#  '. wanted take time shout employee newark airport maxine . wa amazing woman helpful tonight . left passport plane realized after left security made happen could get back . hero .',
#  'proud premier 1k ! flight syd iah ( ua100 ) ! flight attendant polaris wa colombian , brought little bit home , away home !',
#  'man , - guy are awfully stingy . missed requalifying platinum 1 flight , not give status . likely have 60-80 flight year , not',
#  '| returned due cabin . detail :',
#  'ok , well have major # not able watch # live ! hey , when are starting stream live television ?',
#  'airline are treating child like baggage ! junk fee prevention act ! airline charge $ 50 family sit together . want sit plane very curious grandchild ask very good question ? should pay sit together !',
#  'hella chill dude roll anything . , went w flying experience life . wa treated like garbage , rerouted 3 time , delayed 8 hour , offered $ 15 meal voucher trouble . crazy think effed ? !',
#  "big shout pilot flight home last night back scranton got pa system said `` folk , welcome flight scranton . short one . said . ''",
#  "bruh owes many mile flight 2022 bs'ing",
#  'goodness , horror stories.r everywhere ! suuy horrific cruelty inflicted poor dog occured due failure pressurise air cargo ! ccn imagine sufferring incurred ? .',
#  'serious when ask are real price ? like super serious ?',
#  'youth christmas arab emirate ( vote thanks ) 2023',
#  'airline attendant put dog overhead compartment plane flight & amp ; puppy died , surely shld charge animal cruelty ! causing unnecessary death animal e ststesnisnit not ?',
#  '4 million mile & amp ; ton smile ! crew went recognize loyal customer crossing 4mm mark way singapore today ! proud colleague & amp ; entire team sfo !',
#  'annoying thing when trying upload doc app !',
#  'exactly 1 week today turn 31 & amp ; get plane london submit dissertation . people not choose celebrate birthday 8 hour flight , after 4.5 year phd ( & amp ; 25 year school ) mean almost !',
#  'e when book round trip ticket want trip parent united plane . fj ( united express ) jet . stop practice . @ apilots',
#  "`` have put work , '' say captain corey shepard ( ) host 909 morning radio show . take listen have transparent conversation about diversity inclusion aviation . captain shephard proud grad !",
#  "`` please return seat full upright locked position , fasten seatbelt . '' 's denver flight training center . not worry , simulator not real thing !",
#  "today , got email welcoming downgraded status . `` world wonder awaits every time fly united . ''",
#  'exciting catering news : 2-tiered dessert trolley back , feature create-your-own sundae 6 topping option ! better yet , main meal wa actually pretty good . quinoa salad wa tasty , fish entree wa definitely better expected !',
#  'learn something new every time fly zup4ah',
#  'next stop : pdx || road warrior',
#  'thank driving u gate make sure made flight el paso ! proud 1k member !',
#  'nice ! flying bird evening symposium . wish left alone .',
#  'current top 5 shot 777-222/er passing full moon philadelphia photo chris gimmillaro',
#  'downgraded feel like',
#  'get finally use airpods when watching demand movie during flight ! ! thanks excited see everyone 2023 9mo0hz',
#  'anyone have email customer care ? experienced recent trouble wanted email not have send actual letter .',
#  'twitter . aside charge select business class seat ? @ , ? ? ?',
#  'would say major airline , worst , like saying hog shit worst kind shit find .',
#  'evergreen twete',
#  'thank 2023 sponsor : @ worldwide @ premiumaudio wine are grateful support ! q',
#  'point packing light unitedairlines take carry-on put plane anyway ? ? space inside plane put carry-on . not lack space !',
#  'teamwork win championship ! true . 1 g amoveteam @ afety',
#  ', texas san jose del cabo , mexico $ 293 roundtrip ( feb-mar date )',
#  '4 injured after battery catch fire flight',
#  'thanks lift ! great flight today .',
#  'shout , opal rest crew west palm beach airport baggage claim working hard reunite u luggage after dropped ball . look like have rest bag tomorrow !',
#  'why are price high -- going ? ?',
#  '4 people taken hospital smoke inhalation after laptop catch fire onboard plane . flight 2664 returned shortly after takeoff , no flight delayed interrupted .',
#  'copenhagen , denmark $ 424 roundtrip & amp ; ( apr-nov date )',
#  "how `` very difficult decision '' never met , no contact , not phone call , wpp , zoom , not even email ! respond 3 month later saying `` wa difficult decision '' . please ! say no fine . no need compassionate answer ! ; ) hw",
#  'hey where shout ? give ?',
#  'scott kirby & amp ; -- extending premier 1k status , not , 2023 ? not seem right ... want reward loyalty , reward . have not flown non-united flight nearly 10 year have been 1k 8 year . right thing ...',
#  'hat ! flew costa rica ( first time flying united year ) wa obvious have solid system , efficient procedure , employee enjoy job .',
#  'have been loyal customer year . may year airline break loyalty . price fly anywh are always 100 dollar carrier , 0 improvement service justifies want customer pay',
#  'happening uhoea',
#  ": flight san diego newark return airport morning when laptop battery pack caught fire first class ; 7 aboard flight treated smoke inhalation . detail @ 61news ' sister station , @ 8",
#  'top pick travel reward credit card help snag award flight upgrade mile point . . club',
#  'thank prompt service & amp ; assistance ! ! wa able finally use flight credit !',
#  "good evening europe , where landed aboard 's final fleet receive `` real '' polaris seat , boeing 767-400er ! retrofit are finished summer , every int ' l widebody jet feature polaris pod -- major milestone carrier x1tlhit",
#  "faa look fine united airline $ 1.15 million flying boeing 777s 'were not airworthy condition ' via",
#  'terrific morning ride : @ . always bright & amp ; blue friendly sky main line airway : ) go ! rbv5qc',
#  '. ceo & amp ; education workforce committee chair scott kirby workforce development how keep america competitive . read full quote : p44l',
#  'sfo mt 2023 ao supervisor conference .',
#  'wa great speak hemisphere magazine about work ! read full article read hemisphere magazine next flight',
#  'fine , better chaucer , ...',
#  'love pay extra upgrade seat text saying aircraft type changed have different much worse seat result no offer refund seat upgrade',
#  "airplane easy . big deal ? , free highspeed internet ( via wifi ) whole different matter . ps- no thing free . `` free '' get paid somehow .",
#  'after contacting dm regarding refund issue . no acocutability taken end . have been waiting nearly 2 month refund . unable pay rent .',
#  'why fly ? simple ... booked flight , ended operated . e h r delayed ( around 4 plane ) would not even acknowledge . no apology , no compensation ...',
#  'nice decide required check are redundant not . redundancy safety check are purpose . hey , thanks taking safety granted . let alone employee .',
#  'hi - want give shout-out emma ua2431 . wa first day yesterday wa fantastic !',
#  'amazing service staff particular ron bag check . nicest guy ever , give man bonus ! ! !',
#  'flight been delayed 4+ hour please not serving breakfast onboard noon',
#  'airline turf war brewing last week , unveiled new route san diego washington dulles . , adding 4th daily flight route largest jet , 364-seat boeing 777. market support capacity ? time tell !',
#  'holy crap ! flight return airport due laptop fire onboard',
#  'dump ( r ) did know thing like banana peel , stem , leaf , apple core throw-away stuff could one day turned sustainable aviation fuel ( ) help fly plane ? learn about 3be4d',
#  'flying are not nothing fur coat .',
#  'switched 2023 ... unclear like le . watch space insightful observation .',
#  'hand - worst airline , worst costumer service . never again',
#  "could honestly see `` offer , '' like feature -- detail ! design twitter roll revamps lately",
#  'happy tail tuesday den . irport',
#  'phone battery burst flame plane . back gate . thank crew firefighter .',
#  'thanks pqp boost',
#  'lesson learned . carryon bag fit differently others overhead . need direction . kind bag discrimination ? lol',
#  'yi : air-safety regulator are seeking fine airline $ 1.1 million allegedly flying boeing 777 aircraft without conducting certain required check fire-detection system',
#  'said proposing fine airline $ 1.1 million allegedly conducting flight without making required preflight fire system warning check .',
#  'thought wa very cool ! before landing sunday wa handed personalized , hand written , note captain flight . delay wa no big deal- team got u across atlantic safely !',
#  '3 hour morning flight announce while boarding .... bathroom not work . pray family',
#  'dear human being are larger space provide . feel customer have pay not pain , business model may need tweaking .',
#  'really ? 3rd time are trying leave houston , 3rd plane , another mechanical issue ?',
#  "flying yellow backpack long 1st time felt racially bullied steward ua2007 ystrdy . wud not let keep underseat front . bag 17 '' & amp ; meet rule . ignored white psngr 's bigger bag row across aisle . took pix . weird behavior also",
#  ', sweden san juan , puerto rico EUR329 roundtrip & amp ; ( apr-dec date ) z1pc',
#  'new club gate c10 . cool ...',
#  'good morning 788 !',
#  'happy tail tuesday',
#  'united cargo striving keep customer onside , evolve strategic partnership focus re-establishing strong network .',
#  'direct k , thanks',
#  'when africa going get currency style .. st like ot .. e r tog er ck er ap e',
#  'seatbelt extender flight not working . when asked different one , united flight attendant looked like did not know how use ! clarified fly time have been using extenders year . did not believe . 1 / 4 2p',
#  'hey , have been trying refund fully refundable ticket showing flight credit . help !',
#  'delay 1813 # actually longer flight . supposed leave almost 3 hour ago . pushed gate came back , new plane maybe leave 45 min . flight credit gong show .',
#  "turning phone flight plug row 't work .... also no in-seat tv . guess going grab beer sleep , 8 h r !",
#  'week ago tricked day flying 24 hour later promise $ 1k travel certificate never came . man , guy 62 yo . plz halp',
#  'why never fly hour before leave airport flight delayed five hour crew rest ( bad scheduling ) , make miss connection intl flight one per day .',
#  'something about cloud',
#  'ruining diner plan . delayed flight plus took almost hour grab uber . multiple uber driver cancelled took forever connect . uber situation horrendous . need addressed soon possible .',
#  'pair look see may any item address recently arrived background .',
#  'how damage like even happen ? one month old rimowa . one flight united .',
#  'hey houston . friend left something flight ua2049 . did not realize until wa nearly air second leg . would check seat 1e secure item , pretty , pretty please ?',
#  'well after experience think flying next time , reward member why ?',
#  'never fly @ airport always delay delay terrible operation always been case',
#  'happening ! finally way antarctica via santiago , chile . are coming , penguin whale iceberg ... et',
#  'really ? maybe should re-think loyalty',
#  'really impressed service , lounge access etc . have always been unsure about united past pleasantly surprised , given recent horrendous experience , refreshing see good customer service change !',
#  'hey . care train flight attendant ? girlfriend not going trip older woman staff not look crowd behind .',
#  'first time flying new concourse gate irport . gorgeous . apparently going new united club ?',
#  "hey flight attendant yelling while boarding saying `` miss , backup , take 3 step back , know difficult concept , still ! '' while people behind could not move , really not how want start flight . better .",
#  'not sing enough praise club membership . easily switched flight lounge after original flight return airport due landing gear issue . literally took 2 minute get flight leaf 20 minute .',
#  'making pay breach trust crew & amp ; passenger safety first step . airline routinely offshore aircraft maintenance le safe , potentially dangerous facility foreign soil . ew need end horrible practice & amp ; .',
#  'special thanks staff kylie zamantha gate b17 chicago ua953 flight munich went beyond assist . grateful .',
#  '. ew seeking civil penalty against preflight maintenance check n ztzp8',
#  'would any commercial aviation enthusiast find super interesting tweeted number day took someone reach premier 1k status -- based pqfs + pqps . need fly 54 segment 2023 imagine someone reached first 30 day year ?',
#  'want give huge shoutout amazing ticketing agent - thank helping u making experience wonderful',
#  'when give view like',
#  'federal aviation administration said monday proposing $ 1.1 million penalty against airline allegedly failing perform required fire system safety check boeing 777s .',
#  "every time press `` pay '' page refreshes ...",
#  "celebration , houston chapter , 's black business resource group ( ) , welcomed speaker performer honor contribution sacrifice african american have helped shape nation .",
#  'thank taking picture . !',
#  'have asshole ever considered maintenance before plane supposed take ? should have taken .',
#  'wait - paid upon checkin economy plus upgrade boarding group ? not cool , not cool .',
#  'w beyo l r pl ut take need ay',
#  'booked ticket . called time cancel , though wa following day , when finally got , claimed wa past 24-hours gave non-transferable credit . need credit credit card , pay .',
#  'welp lost bag have been wearing clothes 3 day continue until fuck know ! thanks birthday surprise fucking as hat airline !',
#  'happy join celebrated black history month iah ! not forget stop exciting new pop-up exhibit featuring photography marti corn located near gate e10 . kvoqoo',
#  'wonderful flight . thank',
#  'have landed airport ... put bag flight not land hour . wtf ?',
#  'flight price orlando are asinine . are high ? ? ? ?',
#  'miss tulip , ashamed united not incorporated iconic livery current scheme',
#  'should done !',
#  'why come work . besides paycheck feeling when are working team get job done . inside joke make turn feel smooth . lhnphf',
#  'never flying again ... time flying , have never seen conflict between traveler crew regarding timeline update , seating baggage . very poor experience .',
#  'thought wa joke first ! really worth $ 8k upgrade one status level 2023 ?',
#  'hi maybe figure better way u watch ipads ? ?',
#  'j upd : statement proposed $ 1.1 million fine ew missed boeing 777 preflight check ...',
#  "fly . canceled flight due `` maintenance issue '' yesterday . first flight available ( 24 hour later ) wa delayed due `` taking longer expected load baggage '' caused u miss connection again .",
#  'free business travel forum ultimate opportunity hear expert like abe insider secret travel industry ! sign today',
#  'vintage tiki statue keep seeing remind tiki curse episode . ! neokth',
#  'starting colorado ski trip complementary drink food lounge . :',
#  'huge thank rep helped rebook last minute flight . saved trip made day',
#  'celebrating black history month iah 02/06/2023',
#  'have received fresh reminder today why not fly any airline ..... herd customer like cattle , disaster ! ! ! ! !',
#  'boyfriend love spoil .',
#  'hey need help possible . father passed away saturday . any chance one airline could help get son portland , san diego la within next 2 week ? please dm help u .',
#  'love crew !',
#  'thank gate agent worked flight gate b6 morning recognizing 25 year mileage plus member',
#  'are walking aisle credit card application form . have no decency ,',
#  'never flown before . never connecting flight cancelled midair before . neither are true anymore . never again , united . love',
#  ', norway san francisco , usa EUR326 roundtrip & amp ; ( mar-dec date )',
#  'whenever fly boyfriend always make sure squeeze meal',
#  'good morning time fly',
#  'caribbean view something about coming cloud tropic san juan puerto rico day before joining ylsrbl',
#  'hey - father/daughter duo flight deck today - how awesome ! ?',
#  'mr william colvin & amp ; started loyalty back 80 - mr colvin & amp ; congratulation 35th anniversary & amp ; # @',
#  "should flyer get $ 1350 long delay ? think . new push flyer ' bill right + ceo scott kirby why say airline have make change post pandemic success :",
#  'born fly ! irport father~daughter team kane say irport',
#  "breaking social medium silence say complete joke airline . how many `` minor inconvenience '' take make person lose mind ?",
#  'suck',
#  'shoutout gate crew going beyond , without asked , fix glitch get upgrade . 10 10 service . paddington thank !',
#  'international ramp lead agent hillingdon apply :',
#  'never fly nothing like sitting gate watching plane leave missed boarding somehow app check-in wa lost could not print boarding pas . solution wa switch flight add 8 hour travel .',
#  'really wish would have lie flat premium seat seattle boston , nyc airport , miami , atlanta , charlotte , dc , east coast etc . everything 5-7+ hour . fyi , would fly',
#  'first class ticket -h , premier silver status card hundred thousand mile are still not enough privilege . one really confused .',
#  "thing thankful ... made home 5 hour early yesterday ( thanks getting earlier flight ) bonus 's , daughter made delicious strawberry short cake . son say , `` see cooking skipped generation . ''",
#  'want see life empty partially filled flight india .',
#  'club should have king cake time jan 6 - mardi gras day . although have king cake obsessed traveler like frequenting imagine would get quite expensive .',
#  '12-night orlando EUR1,199 per person 9 nov 23 airline flight , including tax bag 12-night rosen inn pointe orlando 2 adult & amp ; 2 kid EUR1,199pp ( 2 EUR1,479pp ) ref : 698725 call u today make booking . 01 8173558sales.ie',
#  'dance scene train station - end slumdog millionaire ( 2 ... 0ko via please sure inquire about bom crew . airline merger trauma survivor folk tell -',
#  'serving new arrival lounge menu @ . fab healthy option well la carte menu . look forward lounge eligible customer feedback week well done head chef george & amp ; team . omra',
#  'get traffic get uber left found scooter road mile did not get caught ar traffic . airport flight about take',
#  'flight ua 759 come full business . ua 2330 show one seat black business . first upgrade list . agent say seat not worked . boarded flight business class seat are taken . mean ? agent friend got upgraded',
#  'upon 737 ... want know , look stranger thing',
#  'where ? wa excited read february issue tonight',
#  'not ever try again ! @',
#  'see ya next year - even agrees exciting way kick ar season ! , time catch reset back .',
#  'bird fly beautiful ocean cancun morning time jan 2023 # ... t0f via',
#  'amazingly strong wave wind cancun beach ... via',
#  'amazingly strong wave wind cancun beach ... via',
#  'amazingly strong wave wind cancun beach ... via',
#  'first flight seattle new york ( jan 19th )',
#  "voice recognition 's customer service line horrendous .",
#  'glad apple help solve lost luggage issue effectively . thanks tracker , saw put luggage plane remove plane . are welcome 1k status , $ $ hole .',
#  "`` not enough ground crew '' are stuck taxiway 15 ' away gate due lack employee ! better @ airport one , not worst !",
#  'ok flight . connected wifi without issue get fo . still not connect .',
#  'another flight , another flight attendant clearly no/minimal training passenger disability . have no issue - canada thing ac thing ?',
#  'moon rising east united flight head west snow covered terrain . absolutely beautiful evening .',
#  'really think get bag faster 50 minute . after 31 hour travel day , are uber one hour after touchdown . why very rarely check bag .',
#  'charter',
#  'flew polaris first time , thanks perk . nice see united flying even short-haul route . pretty good product overall !',
#  'goodbye beautiful bozeman . not sure why downgraded bound plane one fewer seat , rerouted thru seattle . did make worth while end , hope make another trip soon .',
#  'why oh why seem have different wifi network name plan ?',
#  'hey , wife wa forced gate check small carryon last weekend , when got back jewelry wa missing . something ? calling did nothing ?',
#  'hey disappointed baggage service . no one desk . one ticket counter . how get help ? failure',
#  "fly & amp ; fly . & amp ; 's mama fly [ ________ ] ? ? ? v",
#  'fly & amp ; fly -- destined super bowl ! v .',
#  'fuck - made gate check bag did not have any room zsnuh',
#  'awesome team making sure everyone bag are safely . phenomenal job come sunshine , rain , snow . thank !',
#  'kudos flight crew 2/5/23 , . much kindness ! thank !',
#  'dear , not been organizing trip week , would not have known departing leg wa canceled . provided absolutely no email indication canceled leg family trip .',
#  'flying airline been one worst experience . flight delay , poor management disorganized staff .',
#  "blizzard snow scraper courtesy help celebrate national weatherperson 's day !",
#  'should pay directing flight . safe',
#  'no boarding pas needed international flight - scanning face gate match boarding pas . = whole new experience',
#  'trying figure whether not bring couple week , even checked item ... may have give call .',
#  "where 's 777 ?",
#  'remember ... have racist worker san francisco airport ...',
#  'remember ... have racist worker san francisco airport ...',
#  'hey , any chance guy update flight ua4602 ? no one gate mentioning anything app information date . when leaving ? thanks .',
#  '. b777-200er livery irport 06/29/21',
#  '. airiines , have suitcase got shipped mistakenly norfolk , virginia instead dallas last night . using united app seems still not gotten plane back way . help orange suitcase find way home ?',
#  'arriving 777-222 ( er ) n206ua d7',
#  'not know flight attendant aux cord flight , are killing .',
#  'office view 0800 1100 .',
#  'bad day - wa supposed nice business class flight brother film new show la . instead business class - got bumped economy . check took hour no one helping check bag . not premium experience sadly ...',
#  "wanted upgrade flight mile & amp ; wa told mile needed traveler 's account . did , find point needed 1 account . mileageplus claim not xfr point 1 , even point xfrred 20 min earlier .",
#  'thessaloniki , greece $ 446 roundtrip & amp ; ( feb-nov date ) yt83uq5',
#  '2 anymore ? ? ? have 2 upcoming',
#  "sitting tarmac 2+hrs pilot keep coming ridiculous excuse every time . going miss son 's hockey game better ready make keeping coming .",
#  'shoutout manny san diego ticket counter . guy saved missing connecting flight rerouting via denver .',
#  'adopted hometown , , california , seen',
#  'flight ua1914 miami new york/newark delayed unexpected airport facility equipment issue . departs 2:40pm february 5. par course not ?',
#  'hey , how about painted airplane ! ?',
#  'yesterday hit stand goal ( others hit ) watch + would like thank @ 1hr+ precheck line nassau yesterday & amp ; delaying plane & amp ; moving gate 4 time within hour . could not have done without , thank ! ! !',
#  'hey figured would share community travel experience since not get response customer care team after offered 75 buck compensation $ 700 flight wa 5 hour delayed due kick passenger plane , 1/3',
#  "c'mon . are not luddite - like technology . when not book flight website not save info -- would nice chat function connected someone could , like , help ? ! please",
#  'flying sister airline ft. lauderdale-orlando , honeeyyyy smallest plane have ever been . have never seen propeller',
#  'many pilot leaving , , need industry leading contract remain competitive attracting keeping experienced candidate .',
#  'no airline committed upsell add-on miss',
#  'shoutout inflight wi-fi',
#  'attempt 3 getting work where payment lost bag ? reply ....',
#  'aviation profesional loving irport - jonah , thanks do- are truly appreciated !',
#  'not know worse , fact status offer $ 3k fact one moment considered',
#  'always have nice thing say about - time get give .',
#  'nice see airline still strives underwhelm disappoint .',
#  'well , wa not going post still amazes have people no common sense make decision . 1 ) after 7yr hiatus decided give chance again ( minus c wa flying 200k+ mile w/ wa 1k last 6yrs 2023 )',
#  'honestly , joy gate restored faith entire airline might start flying ... whole team wa amazing morning .',
#  'malta take security council presidency s0jw via nation western europe',
#  'god sorry -- different ridiculous . fix .',
#  "last min trip weekend . got call tuesday 3pm `` monday morning ? '' yes ! booked & amp ; prayer monday & amp ; thanks have donated ! last min plan are expensive , could not have done w/out .",
#  'loving legroom seat 7d ! way economy plus seat , wa $ 119 flight thanks silver status , wa able pick seat e checkin',
#  'automated text say bag wa delivered still not . not very good system',
#  'still missing luggage denver . still not updating status .',
#  'really tried not drag online about mountain issue experienced trip december after month trying get customer service rep phone . go ! ( th )',
#  'come . come girl trueing get home . been long night/morning .',
#  'flight wa supposed start boarding 25 minute ago , still no crew , not board . full flight , going make connection challenging flight late .',
#  'welcome ! proud official airline',
#  'well done , enjoyed ewr -- & gt ; ord .',
#  'great job mariah laura providing service passenger ua2666 ! flight departed 10 minute early contribution ! thankful amazing team !',
#  'girl terminal b eating chicken strip 8:59am , vibe .',
#  'haha tried charge $ 740 change ticket later flight when purchasing one way flight separately would have cost $ 320 ? ? needle say canceled return leg partial credit bought one way home $ 255',
#  'one favourite see mighty impressive 767-424 ( er ) low landing line gear ready touch . impressive get close h 8',
#  "`` zone floor '' full effect morning irport ! kevin briefing u are planning ahead ensure have operation passenger ! great collaboration between department ! 6qsxf",
#  'asked glass water 1st class cabin while gate . attendant refused said would serve air ! way treat premier 1k flying 17hrs international flight could not find time stop before local connection',
#  'major airline ranking : 1 . 2 . 3 . 4 . 5 . 6. united far away worst . fly find . have no idea how treat customer have flown airline year !',
#  "yo . why flight smell like rubbing alcohol icy hot . c'mon . understand cleaning , gone high shit time land , lol",
#  'hey - many thanks gentleman working d40 terminal 2 ( akmel ? ) . very helpful , very upbeat arsenal fan .',
#  'every time fly swear last time fly',
#  'last night united 737-200 united747-400',
#  'day travel not encounter * any * issue . not today .',
#  'beautiful morning flying . 2',
#  'yet again gate flight z recognition hard hearing disability . even asked assistance explaining not hear announcement wa brushed aside . have sue someone take note not disability are visible ? ! ?',
#  '787 16000ft routing houston morning . @ acaster',
#  '767 13000ft routing morning . @ acaster',
#  '767 16000ft routing @ airport morning . @ acaster',
#  'another sunday morning , another flight',
#  '7-nightnew york & amp ; la vega EUR1,359pp 1 sep 23 airline flight , incl tax & amp ; bag 3-night kixby hotel new york 4-night paris la vega resort casino 2 adult sharing ref : 698720 call u today 01 8173558sales.ie',
#  'about fly phoenix ! thanks helping get !',
#  'pilot walked around departure gate personally welcomed every passenger flight after giving u briefing pa system . shockingly effective service recovery previously canceled flight .',
#  ', belgium new york , usa EUR228 roundtrip & amp ; ( mar date )',
#  'every time fly orlando always damn problem',
#  'awesome !',
#  'dear understand thing are rough . work big tech are struggling . said , temporarily removing someone flight while are mid flight shitty .',
#  'hi fly sfo yul air canada ( no code share ) access lounge ? 1k/1m .',
#  "plane mid-air way london . diverted halifax canada . b ' h oos",
#  "hey would help stay united wife ? flying feb 12th . any secret surprise valentine 's day . would definitely cherish year come .",
#  'damn united airline did dirty told not nothing about like spirit zugx',
#  'hey - been 50 min counting since flight landed @ airport still waiting luggage . almost 1am . could better ?',
#  'first time flying since lost bag last time . ... lost again . delay reimbursement system error , not issue reimbursement . , wa hold 45 minute agent answered immediately hung . last time make mistake .',
#  'thank upgrading first class seat flight back home . really helped allow rest left leg post reconstruction surgery .',
#  'thank wasting 6 hour life cancel flight & amp ; continue waste time . sorry did not book',
#  'arriving airport new colour',
#  'tail never fails ! head tail interactive raffle brought ball sponsor !',
#  'amazing volunteer hosting distribution while wa work addition chicken , milk , produce box , received approx 100 dozen egg week',
#  'hey have not flown guy year remembered why . 7:58 flight newark saint louis wa delayed least 90 minute ( 70 counting still not aircraft yet ) shuttle driver gate staff are yelling .',
#  'well cancelled direct flight between tokyo honolulu . way go . massive expense did not count , have go another airline . no press statement either , silent cancellation within 60 day departure .',
#  'did forget @ @ never asked permission violating constitutional aka right hokus bull @ @ would not ? effect ?',
#  'captain see two open gate not bothered get u one after 40 minute sitting active taxiway . level incompetence .',
# ...
#  'come get boy home quicker ! !',
#  'greeting everyone , home office # kq would like continue support # kq art & amp ; spatial pro guide & amp ; percussion section jazz you.s . check entire fleet - gotcha covered ! halo angel fish',
#  'united , tallgrass , green plain form joint venture develop new sustainable aviation @ c',
#  'lost flight connection airline not give 15 dollar eat when are responsibility nobody help',
#  'today paid $ 62 sit next wife infant flight . thanks still making air travel hellscape .',
#  'may not everyone favorite season , sure interesting addition photo ! irport',
#  "top story today : : 'farewell ( again ) , . after 50 year , delivering final 747 ever made . drop favorite pic majesty . ' see",
#  '. , green plain invest $ 50 million joint blue blade energy @ c # technology',
#  'shame . two suitcase destroyed . even broke wheel .',
#  'since officially crossed international date line , early courtesy humkb',
#  'ux shitshow app experience . not upgrade , use chat , link pay chat , submitting form crash app .',
#  's/o crew wishing happy birthday ! wa , always been , safe relaxing trip ! 9ezlt0',
#  'come help ..... ?',
#  '10 hour flying get mexico ! absolutely worth every second ! serious deal got kicked vacation right gear !',
#  'team den house ! represent ! # eadershipconference',
#  'suggestion - offer tequila flight , least to/from mexico',
#  'danesh visiting after ao conference ! enjoy meeting connecting lovely friend across pond ! miss !',
#  "celebrating lynneette 's 10th . are . pro lobby , gate , & amp ; ops . , irport",
#  'let u ! & amp ; are ready get underway ! future h ! 2 new aircraft introduced fleet every week ! bring well way best airline history aviation !',
#  'got meet delhi family ! connecting people , uniting world 4qu',
#  'great start 2023 ao leadership conference ! thanks made great event reality ! team den even managed get photo man ... lady & amp ; gentleman ... mr. !',
#  "united graduate first class aviate pilot academy `` united 's aviate academy flight school operated major airline . ''",
#  'awesome 2023 supervisor conference !',
#  'straight changed phone plan thought would get free wifi flight . turn cell phone',
#  'team- wish e. lorenzo happy 17th birthdaythank flying u ogp n',
#  'united canceled flight cancun no alternate option dec 23 due lack pilot @ airport . vacation wa booked united , could not travel . even after 5 week follow-up , have no refund hotel .',
#  'tail tip tuesday',
#  'loyal hell , not lie : drive nut brother fly business class europe twice year 1k fly 50+ time year ( 106 one year ! ) not get higher platinum . no love u short-haulers , truly frequent flyer .',
#  'hey flight chicago kansa pleeeease not go without u ! got flight dublin waiting bag ar farthest possible carousel',
#  '[ airline review ] overall very nice business class experience , elevated visit fabulous polaris lounge',
#  '& amp ; seat mate scrub seat & amp ; tray ask flight attendant wipe whatever wa seat wa window . cabin wa hot did not have engine power opened back door plane',
#  'hey why every time fly , allow carry-ons forcing check carry-on ? last flight wa gu r wa allowed carry-on , mine checked . keep thing carry-on not lose - medication custom fit clothing .',
#  'been stuck airport day , are not mad . l-i-v-i-n , know ! love !',
#  'special thanks airline holding flight 1170 31 jan / due late arrival .',
#  'today hygiene theater , maskless flight attendent told passenger could not pour water directly baby bottle ... c d. poured plastic cup . public health expert see logic , let know .',
#  '. app god-awful',
#  'umm how long after trip take flight mile pop account',
#  'airport , cancelled flight booked u different aircraft . son sobbed missed opportunity . connected husband , never got fly 747 . 2/3',
#  'welcome polaris , cleaning crew continue disappoint . lot crumb seat garbage left behind . ua1474 3a',
#  'flying back nj . make flight go bit quicker . kick as ! % liverock !',
#  'feel good see tail .',
#  'hey , never fly -- make status match offer , take money -- find loophole say are not going fulfill end deal . trash operation .',
#  'might wrong think something missing external luggage pocket recent travel - not expensive valuable , annoying , . remember putting last minute thinking nobody would bother looking pocket notice anything .',
#  'should book ? ? ? ? ? ? ? ? not know omg . better ........',
#  'technology , successful development , convert ethanol feedstock low-carbon fuel',
#  'flying tomorrow nicaragua',
#  'ok , hear : flight leaf 6pm . land 12am . why not get forever promise not talk about online until land ?',
#  'thankful finding plane crew get very delayed flight ground tx . thank not canceling leaving u stranded',
#  'dearest sponsor partner , would anitta performance , , , , , , , , , , frontera , , @ xm serve official partner 2023 y .',
#  'new ( columbus , ohio ) family , thank everything ! wa great experience working , extremely proud everyone new member ! wa honor able help train trainer ! miss ! @ afety',
#  "are tomorrow 's flight dfw still happening ? hear delay cancellation . should try reschedule flight ? option ?",
#  'playing piano @ airport terminal c. one fave january moment ! wa playing w :',
#  'hey nice touch scott c. sfo 901 united . been loving flying friendly sky lately . crew have been great .',
#  ', chile los angeles , usa $ 451 usd roundtrip ( apr-may date )',
#  'thank laguardia gate agent rasha getting earlier flight amidst delay today , not miss connection . credit company , united !',
#  "`` about finding right talent place have not been reached before . '' meet juan , wa recently accepted 's program . story . |",
#  'winterization item are needed energy crisis cold temperature exacerbate humanitarian need . help , 23 pallet sleeping bag , blanket , hygiene item are departing headed ukraine behalf nonprofit e .',
#  'rough travel day texas ... good photo deicing definitely not debating need !',
#  'shout crew took care wife flight ua 1357. wife wa feeling really sick accommodated u every step way ! unsure flight attendant name did everything make u feel comfortable !',
#  'non-stop , puerto rico new york , usa $ 216 usd roundtrip ( apr-may date )',
#  'ride rail adventure add dash adventure commute . chance win EUR100 voucher ! enter : take selfie united skyline luas ( greenline ) post story tag tour america 30 jan - 5 feb',
#  'always enjoy flying boeing triple 7 . bonus seeing rockies',
#  'thanks crew ua439 mci working extra get guitar stowed . not mine ; not know owner , assume are en route tnx treating musician properly !',
#  "lmao delayed flight god know why pilot wa like `` lol have no fuel '' actual fuck",
#  'help ? ? ?',
#  'great thing seem happen whenever travel - like always getting best food tour getting upgraded first class how',
#  "week touch arizona , relo town ! ceo moderate ' talk about woman sport marketing representative , , , . a2fp",
#  'nothing like no idea where bag are . like 20 passenger did not get bag sfo no one know exactly where are . help ! ! ! !',
#  'honor may suggest checking fab place airline partner fly',
#  "today fly mother 's birthday when always feel closer . happy heavenly mommy . miss love .",
#  'punched ticket sunday . planning travel arizona support bird ? , , offer nonstop flight irport . check airline schedule , price & amp ; availability .',
#  'way nyc 16 day ago , flight wa delayed total 1.5hrs ... trying go home , delayed almost 1hr already . please get stuff together ... ridiculous .',
#  'frustrating when overzealous staff make check bag when still plenty bin space available . know are trying load plane big impact efficiency air travel business .',
#  'hey , according gelatin not vegetarian , recline box label gummy bear vegetarian . have special vegetarian gummies specially-made ? not , seems urgent muslim , kosher folk , vegetarian . where report ?',
#  'farewell ( again ) , . after 50 year , delivering final 747 ever made . drop favorite pic majesty .',
#  'wa flight ua 2326 -iah saturday 01/23 & amp ; handicap hanger wa stolen bag . have witness took rent car & amp ; put bag . wa not upon arriving ! make very difficult get ahold someone report .',
#  'looking forward learning about project working possible positive impact have agriculture ethanol industry !',
#  '. , , , , , , , , , , frontera , , @ xm serve official partner 2023 y .',
#  'not first not putting bag checked gate right plane not delivering bag day like told would proceeding deliver wrong bag not taking any accountability',
#  'congratulation , @ c ! great see company pulling direction sustainable aviation fuel . #',
#  "green plain ceo todd becker join tv discus newly announced joint venture . `` one best venture have seen alcohol-to-jet green plain sits right middle . ''",
#  "sad lose 1k status , also , `` offer '' pay nearly $ 4,000 keep 2023 ... seriously , ? not offer .",
#  'rotation balance : place credit card upright position # @',
#  'time plan celebration ! low fare alert chicago aboard . time fun !',
#  'sharpen skill un e-learning course via nation western europe',
#  'los angeles , including universal hollywood park ticket EUR1,399pp 14 sep 23 airline flight , incl tax bag 6-nights tilt hotel universal/hollywood 2 adult sharing ref : 698596 call u today book offer . 01 8173558sales.ie ynxvowm',
#  ', soooooo , back where started month ago ? think offer full refund again ?',
#  'last day global service . thank 4 amazing year . know still treated incredibly well 1k , miss bat phone number fix every problem . every touchpoint ( phone line , airport check-in , gate agent ) been a+ . amazing employee .',
#  "love pilot ! said , `` let u go fly ! '' . well , let u go !",
#  'beyond ridiculous point .',
#  'someone please help understand craziness ! !',
#  ', canada cancun , mexico $ 445 roundtrip ( jan-feb date )',
#  ', guess are not done yet !',
#  'have been stuck flight nearly 2 hour someone not read weather report see freaking ice plane ? going miss connection , god know when see luggage again .',
#  'beyond comprehension right thing provide basic customer service ? ? ? ? would say unbelievable yet , seems common airline .',
#  ', see , have been dealing month ineptitude various folk say refund request oh wait , see no refund request . after multiple phone call dm twitter , seems no longer speak ?',
#  'united , tallgrass , green plain form joint venture develop new sustainable aviation fuel technology using ethanol : @ c',
#  '11-night stay universal orlando resort fr EUR999 pp 22 apr 23 airline flight , incl tax bag 11-night , universal endless summer resort- dockside inn suite 2 adult & amp ; 2 kid EUR999pp ( 2 adult EUR1,399pp ) 698594 call u today 01 8173558 sales.ie',
#  "see , why people have hard time understanding definition `` customer service '' . see entire conversation thread .",
#  'real treat morning . 787-10 - den . favorite aircraft !',
#  'shoutout irport-based customer service rep carla consistent positive superb assistance . positioned premier check-in early morning . good person , always wonderful rep united , see quite bit !',
#  ', sweden burbank , california EUR337 roundtrip & amp ; ( apr-may date )',
#  '6-night san francisco EUR1,199 per person 24 may 2023 airline flight , including tax bag 6-nights pickwick hotel san francisco 2 adult sharing alcatraz cruise day tour included ref : 698589 call u today 01 8173558sales.ie',
#  'sustainable aviation fuel ( ) best tool airline have reduce emission , have supply problem . see how leading effort change :',
#  'beautiful boeing 787-9 second arrival back 2017',
#  'education first step take quick read short article how education instrumental every step take . nation',
#  ', canada bahamas $ 416 roundtrip ( feb-mar date ) qoiu',
#  'foggy start seen security checkpoint expansion construction site . 3880 departing ua4464 . project expand checkpoint four lane , expedite screening process improve passenger experience .',
#  'hello - how speak one service desk agent while india ? whatsapp option ? need call delhi number ?',
#  'b k : today , green plain announced joint venture airline develop commercialize novel sustainable aviation fuel technology . read announcement :',
#  'major kudos captain forward cabin crew flight 2416 1/30-31 . passenger f/c kind medical emergency before take , everything wa handled calmly professionally despite leaving sfo hour late , arrived 8min behind sched',
#  'welcome supervisor conference . e # united nited #',
#  "25 minute past boarding time still waiting crew member `` missed shuttle ''",
#  'baby cold outside ! making happen team - day bar .',
#  'every time think ok not fly delta always get screwed . last year departing returning flight got canceled , none bathroom flight are working have return gate . sorry betrayed',
#  'happy tail tuesday !',
#  'have nice day everyone stay safe . keep smiling family @ afety',
#  "hey q , kind @ program sign get accosted belligerent salesperson way precheck ? point might even go `` no ! '' face tattoo .",
#  "universal fun sun fr EUR899 pp 2 sep '23 airline flight , incl tax bag 12-nights universal endless summer resort - dockside inn suite 2 adult & amp ; 2 kid EUR899pp ( 2 adult EUR1,229pp ) ref 698527 call u today . 01 8173558 sales.ie",
#  'hey service suck',
#  'small sb flight vibe right',
#  'pre-paid wifi fraud . when are onboard , not option recognizes pre-purchase ; even when log account .',
#  'again go another treasure even though not get paid free ad , never change airline',
#  'dear are 50 country world . how f * * * supposed buy ticket . not wait day go bancrupt',
#  'hey not find trip confirmation number h5n0yn thanks',
#  'view flying salt lake city flight 354',
#  'one day closer stunning view . ready ? . . . . aerial shot day presented airline .',
#  'hey - bag did not travel sydney canberra - still sfo . update mean are sending new zealand first ? ?',
#  'touch iah thanks',
#  'starlit celebration . entire team celebrated first place ua r competition fourth quarter 2022. thanks entire team ! ! !',
#  "much prop winning bronze `` agent demand ''",
#  "honestly fuck , not schedule short layover o'hare",
#  'hey ! how about actually find luggage stop telling next flight ! 4 flight have flown ! lost say !',
#  'excited help chief fan get game irport are ready red kingdom',
#  'okay , how charge $ 1.99 1 hour internet , $ 5.99 2 hour flight ? mean , cheaper getting two 1-hour package one 2-hour package . missing something ?',
#  'one punished outage passenger day outage . especially passenger .',
#  'okay , going brag . 2022 earned platinum 1k . ( aided eased covid requirement , ignore ) . never thought would have highest premium status two different company !',
#  'heading back city courtesy',
#  'hey , cool hold flight passenger late inbound connection , why board everyone else time force sit 70 minute ?',
#  "fresno 's airport record number passenger 2022. likely grow , prepare add flight coming month . gyj",
#  'cheating tonight ( schedule dictated ) , not worry , american , back later week . please not exact revenge any weather delay disruption .',
#  'airplane equipped rain enhancement system help mitigate impact environment , thanks . pictured also applicable , , , . $ $',
#  'shoutout janine ua 879 number u did not have headphone before 11 hour flight . helped get everyone sorted before takeoff !',
#  "first time fly ye & amp ; quickly remembered why stopped flying . delayed flight slc crew hotel `` power outage '' ( called hotel & amp ; reported no thing ) 3 hr late pilot stayed hotel & amp ;",
#  'well reported story . wonder board member like professor robert alpern president brett hart think about ?',
#  'disappointment based set level expectation . many delayed flight airline , no longer upset . expectation .',
#  'flight leaving dallas wa late , flight leaving dallas been sitting waiting leave like hour . better',
#  'well done ! delay suck clearly airport dictated , yet sent $ 15 qr code snack while wait . 1k never gotten consideration . thanks !',
#  ...]

# %%
# load model
model = models.load_model('models/models.h5')

# load tokenizer
with open('tokenizer/tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

X_test_token = tokenizer.texts_to_sequences(X_pred)

X_test_pad = pad_sequences(X_test_token, dtype='float32', padding='post')

y_pred = model.predict(X_test_pad)
# Out:
# 2023-03-11 14:02:22.319889: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-03-11 14:02:22.319931: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-03-11 14:02:22.319993: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (LAPTOP-2PJA6S06): /proc/driver/nvidia/version does not exist
# 2023-03-11 14:02:22.320301: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 131/131 [==============================] - 3s 9ms/step

# %%
y_pred
# Out:
# array([[0.29182982],
#        [0.57226753],
#        [0.09552934],
#        ...,
#        [0.31137756],
#        [0.99067503],
#        [0.09553356]], dtype=float32)

# %%
df['pred'] = [1 if i[0] > 0.5 else 0 for i in y_pred]

# %%
df['clean_text'] = X_pred

# %%
df.to_csv('predicted_tweets.csv', index=False)

# %%
df = pd.read_csv('predicted_tweets.csv')

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df = df.groupby(df.date.dt.day)['pred'].mean()
